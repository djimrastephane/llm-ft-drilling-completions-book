# %% [markdown]
# # Chapter 3 explore: Baseline Prompting: What the Model Gets Wrong Before Fine-Tuning
#
# STATUS: placeholder notebook -- not written yet. Once `code/chapter_03/baseline_prompting.py` exists, use this notebook to interactively explore it, mirroring the previous book's `notebooks/chapter_NN_explore.ipynb` convention.

# %%
# TODO: import and exercise code/chapter_03/baseline_prompting.py here.
