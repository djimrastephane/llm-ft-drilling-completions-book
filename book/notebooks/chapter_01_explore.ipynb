# %% [markdown]
# # Chapter 1 explore: Loading and Running Your First Local LLM
#
# STATUS: placeholder notebook -- not written yet. Once `code/chapter_01/load_local_model.py` exists, use this notebook to interactively explore it, mirroring the previous book's `notebooks/chapter_NN_explore.ipynb` convention.

# %%
# TODO: import and exercise code/chapter_01/load_local_model.py here.
