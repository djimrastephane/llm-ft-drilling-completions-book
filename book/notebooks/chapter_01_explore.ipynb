# %% [markdown]
# # Chapter 1 explore: Loading and Running Your First Local LLM
#
# Interactive companion to `code/chapter_01/load_local_model.py`. Run the cells below one at a time (Shift+Enter) to load the base model once and try your own questions against it, without re-downloading or re-loading between tries.

# %%
import sys
sys.path.insert(0, "../code/chapter_01")

from load_local_model import MODEL_NAME, load_model_and_tokenizer, generate_reply

model, tokenizer = load_model_and_tokenizer(MODEL_NAME)
print(f"Loaded {MODEL_NAME}")

# %%
question = "In one sentence, what does 'trip out of hole' mean?"
print(generate_reply(model, tokenizer, question))

# %% [markdown]
# Try your own question below -- something from your own role (completions, intervention, production). Notice whether the answer references anything specific to your operation, or stays generic.

# %%
my_question = ""  # TODO: type a drilling or completions question here
print(generate_reply(model, tokenizer, my_question))
