# %% [markdown]
# # Chapter 4 explore: Tokenization and Embeddings for Domain Fine-Tuning
#
# STATUS: placeholder notebook -- not written yet. Once `code/chapter_04/tokenize_and_embed.py` exists, use this notebook to interactively explore it, mirroring the previous book's `notebooks/chapter_NN_explore.ipynb` convention.

# %%
# TODO: import and exercise code/chapter_04/tokenize_and_embed.py here.
